# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.9/818.9 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 5.5 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://tracy-nondoubtable-rose.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://tracy-nondoubtable-rose.ngrok-free.dev
# True

# %%
from google import genai
from google.genai.types import Tool, GenerateContentConfig, GoogleSearch

# === 初始化 Google Gemini ===
client = genai.Client(api_key=gemini_api_key)

google_search_tool = Tool(
   google_search=GoogleSearch()
)

chat = client.chats.create(
    model="gemini-2.5-flash",
    config=GenerateContentConfig(
        system_instruction="你是一個中文的AI助手，請用繁體中文回答",
        tools=[google_search_tool],
        response_modalities=["TEXT"],
    )
)

# %%
def stateful_query(payload):
    response = chat.send_message(message=payload)
    return response.text

# %%
result = stateful_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學（Minghsin University of Science and Technology），簡稱明新科大，是一所位於台灣新竹縣新豐鄉的私立科技大學。
#
# **歷史沿革**
# 明新科技大學的創校可追溯至1966年，當時是以「明新工業專科學校」立案。 爾後，學校歷經多次改制與更名：
# * 1993年，更名為「明新工商專科學校」。
# * 1997年，改制為「明新技術學院」並附設專科部。
# * 2002年9月，升格為科技大學，定名「明新科技大學」。
# * 2018年12月，更名為「明新學校財團法人明新科技大學」。
#
# **辦學理念與特色**
# 明新科大秉持「堅毅、求新、創造」的校訓，其校名「明新」取自《大學》中的「在明明德，在新民，在止於至善」之精義，旨在培養學生高尚品德、專業學問與優良技術。 學校的願景是成為「一流產業大學」，並以培養「跨域整合、務實創新、全人學習」的專業人才為教育目標。
#
# 明新科大在辦學上具有以下特色：
# * **產業連結深厚**：學校座落於桃竹苗產業中心，鄰近科學園區與工業區，積極與產業合作，例如攜手國際封測大廠成立「半導體封裝測試產業聯盟」，為半導體產業聚落提供人才。
# * **前瞻性學術發展**：明新科大緊跟產業趨勢，鎖定半導體、AI、元宇宙、風電綠能等前瞻產業發展。 更率先設立全台第一個「風力發電學士學位學程」，並於2022年獲教育部核准通過「半導體科技博士學位學程」，這是學校成立以來第一個博士班。
# * **多元與國際化學習**：學校推動多元學習，將程式設計與人工智慧課程列為大一必修學分，並導入AI與AR情境學習。 在國際化方面，除與菲律賓大學有雙聯學位，也與澳洲西雪梨大學、越南胡志明市經濟大學簽訂合作備忘錄，推動跨國雙聯學位教育模式。
# * **企業肯定**：在2022年《遠見》雜誌的「企業最愛公私立技職科大調查」中，明新科大在四大領域中獲得兩項企業最愛，起薪排名私校第一，優於部分國立科大。
#
# **學院與學系**
# 明新科技大學現設有六個學院，包括：
# * 半導體學院
# * 工程學院
# * 管理學院
# * 民生學院 (亦稱服務產業學院)
# * 人文與設計學院 (亦稱人文社會學院)
# * 共同教育學院
#
# 這些學院涵蓋了多個學系、碩士班及學士學位學程，例如機械工程系、資訊工程系、電機工程系、企業管理系、旅館管理與廚藝創意系、多媒體與遊戲發展系等。
#
# **校園環境**
# 明新科技大學位於新竹縣新豐鄉，佔地逾三十公頃，交通便利，校園環境優美。

# %%
result2 = stateful_query("校長是誰？")
print(result2)
# Out:
# 明新科技大學現任校長為呂明峯教授。他於2025年2月1日正式上任，是該校第11任校長。呂明峯校長從卸任的林啓瑞校長手中接下印信，他將運用其豐富的半導體教育與產業實務經驗，並以「四大核心模組」的校務治理策略，帶領明新科大開創技職教育新局。

# %%
from flask import Flask, request, abort
import logging
import os
import time
from google.genai import types

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    MessagingApiBlob,
    ReplyMessageRequest,
    TextMessage
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
    FileMessageContent
)

app = Flask(__name__)

logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
app.logger.setLevel(logging.INFO)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)

# 儲存檔案的目錄
UPLOAD_DIR = "/content/uploaded_files"
os.makedirs(UPLOAD_DIR, exist_ok=True)

# 儲存每個使用者的對話 session 和上傳的檔案
user_sessions = {}  # {user_id: {"chat": chat_object, "uploaded_file": gemini_file}}

def get_user_session(user_id):
    """取得或建立使用者的對話 session"""
    if user_id not in user_sessions:
        # 建立新的對話 session
        new_chat = client.chats.create(
            model="gemini-2.5-flash",
            config=GenerateContentConfig(
                system_instruction="你是一個中文的AI助手，請用繁體中文回答。如果使用者有提供參考文件，請根據文件內容回答問題。",
                tools=[google_search_tool],
                response_modalities=["TEXT"],
            )
        )
        user_sessions[user_id] = {
            "chat": new_chat,
            "uploaded_file": None
        }
    return user_sessions[user_id]

def download_line_file(message_id, file_name):
    """從 LINE 下載使用者上傳的檔案"""
    with ApiClient(configuration) as api_client:
        line_bot_blob_api = MessagingApiBlob(api_client)
        file_content = line_bot_blob_api.get_message_content(message_id)

        file_path = os.path.join(UPLOAD_DIR, file_name)

        with open(file_path, 'wb') as f:
            f.write(file_content)

        return file_path

def upload_file_to_gemini(file_path):
    """上傳檔案到 Gemini Files API"""
    uploaded_file = client.files.upload(
        file=file_path,
        config={'display_name': os.path.basename(file_path)}
    )

    # 等待檔案處理完成
    while uploaded_file.state.name == "PROCESSING":
        print("檔案處理中...")
        time.sleep(1)
        uploaded_file = client.files.get(name=uploaded_file.name)

    if uploaded_file.state.name == "FAILED":
        raise Exception("檔案上傳處理失敗")

    return uploaded_file

def query_with_rag(user_id, question):
    """使用 RAG 模式回答問題"""
    session = get_user_session(user_id)
    uploaded_file = session["uploaded_file"]

    if uploaded_file:
        # 有上傳檔案，使用 RAG 模式
        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=[
                types.Content(
                    role="user",
                    parts=[
                        types.Part.from_uri(
                            file_uri=uploaded_file.uri,
                            mime_type=uploaded_file.mime_type
                        ),
                        types.Part.from_text(text=f"請根據上述提供的檔案內容，用繁體中文回答這個問題：{question}")
                    ]
                )
            ]
        )
        return response.text
    else:
        # 沒有上傳檔案，使用一般多輪對話
        response = session["chat"].send_message(message=question)
        return response.text

@app.route("/", methods=['POST'])
def callback():
    signature = request.headers['X-Line-Signature']
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature.")
        abort(400)

    return 'OK'

@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    """處理文字訊息"""
    text = event.message.text
    user_id = event.source.user_id

    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)

        if text.startswith('AI '):
            prompt = text[3:]
            try:
                # 使用 RAG 或一般對話
                reply_text = query_with_rag(user_id, prompt)

                # 檢查是否有上傳檔案，加上提示
                session = get_user_session(user_id)
                if session["uploaded_file"]:
                    reply_text = f"📄 [RAG 模式]\n\n{reply_text}"

                line_bot_api.reply_message_with_http_info(
                    ReplyMessageRequest(
                        reply_token=event.reply_token,
                        messages=[TextMessage(text=reply_text)]
                    )
                )
            except Exception as e:
                line_bot_api.reply_message_with_http_info(
                    ReplyMessageRequest(
                        reply_token=event.reply_token,
                        messages=[TextMessage(text=f"❌ 發生錯誤：{str(e)}")]
                    )
                )
        elif text == "清除文件":
            # 清除使用者上傳的檔案
            session = get_user_session(user_id)
            session["uploaded_file"] = None
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text="✅ 已清除上傳的文件，恢復一般對話模式。")]
                )
            )
        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text="請輸入「AI 問題」來開始對話\n或上傳 TXT/PDF 檔案啟用 RAG 模式")]
                )
            )

@handler.add(MessageEvent, message=FileMessageContent)
def handle_file_message(event):
    """處理使用者上傳的檔案"""
    user_id = event.source.user_id
    file_name = event.message.file_name

    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)

        # 檢查檔案類型
        if not (file_name.endswith('.txt') or file_name.endswith('.pdf')):
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text="⚠️ 目前只支援 TXT 或 PDF 檔案")]
                )
            )
            return

        try:
            # 下載檔案
            file_path = download_line_file(event.message.id, file_name)
            print(f"檔案已下載：{file_path}")

            # 上傳到 Gemini
            uploaded_file = upload_file_to_gemini(file_path)
            print(f"檔案已上傳到 Gemini：{uploaded_file.uri}")

            # 儲存到使用者 session
            session = get_user_session(user_id)
            session["uploaded_file"] = uploaded_file

            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=f"✅ 檔案「{file_name}」上傳成功！\n\n現在您可以輸入「AI 問題」來詢問關於這份文件的問題。\n\n輸入「清除文件」可恢復一般對話模式。")]
                )
            )
        except Exception as e:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=f"❌ 檔案處理失敗：{str(e)}")]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# INFO:__main__:Request body: {"destination":"U967a7ddada8eaab9e15d60d0f3029ae7","events":[{"type":"message","message":{"type":"file","id":"594033467029979244","markAsReadToken":"lIiCGJYr-TB5qtQeBsm9W1EbZblPWzP4apL-loSrMpeYxTqWP9nwfPhwnkR-Zxyhhd8Np7diJ9YzfJ0da0b8hbv9-XUjCBKYoWD7UsUhhsWkcXfTFV7vu5kejdKYC4RqvMgK6-05JBjItsxKJFHY-btXcLjxEx4CIWT1PcYplMbefcZ8KcgYJFI2f-WCdKtU_S35WOrGm4VchpTlgJlxoA","fileName":"faq.txt","fileSize":56,"contentProvider":{"type":"line"}},"webhookEventId":"01KDHSVGP8ZB32YN0XMASJK841","deliveryContext":{"isRedelivery":false},"timestamp":1766902842003,"source":{"type":"user","userId":"U63019324a610a0977db9bdaed8d8f469"},"replyToken":"a95a160891514ce88009a74df5fdc641","mode":"active"}]}
# BODY:  {"destination":"U967a7ddada8eaab9e15d60d0f3029ae7","events":[{"type":"message","message":{"type":"file","id":"594033467029979244","markAsReadToken":"lIiCGJYr-TB5qtQeBsm9W1EbZblPWzP4apL-loSrMpeYxTqWP9nwfPhwnkR-Zxyhhd8Np7diJ9YzfJ0da0b8hbv9-XUjCBKYoWD7UsUhhsWkcXfTFV7vu5kejdKYC4RqvMgK6-05JBjItsxKJFHY-btXcLjxEx4CIWT1PcYplMbefcZ8KcgYJFI2f-WCdKtU_S35WOrGm4VchpTlgJlxoA","fileName":"faq.txt","fileSize":56,"contentProvider":{"type":"line"}},"webhookEventId":"01KDHSVGP8ZB32YN0XMASJK841","deliveryContext":{"isRedelivery":false},"timestamp":1766902842003,"source":{"type":"user","userId":"U63019324a610a0977db9bdaed8d8f469"},"replyToken":"a95a160891514ce88009a74df5fdc641","mode":"active"}]}
# 檔案已下載：/content/uploaded_files/faq.txt
# 檔案已上傳到 Gemini：https://generativelanguage.googleapis.com/v1beta/files/zml1hzsom2vw
# INFO:werkzeug:127.0.0.1 - - [28/Dec/2025 06:20:44] "POST / HTTP/1.1" 200 -
# INFO:__main__:Request body: {"destination":"U967a7ddada8eaab9e15d60d0f3029ae7","events":[{"type":"message","message":{"type":"text","id":"594033499427307708","quoteToken":"MzsCpkG_hURPbOrOgWCkhPFejryrshIrTl_0gYkVLnlgZzSY1kjTDiqF1NL0MXT0BDqv9MGAuCqBqMUli8yk6zmorkT2Gv449BvN8J1o1Dpz6dw6dAmhvG_oPgP5zF353G68tAzIYg2n2ssk3BlpQA","markAsReadToken":"Z5YmbPubtpgAcLv5OrJTVVEywZ1g56uv5_9z6VjwDUa35LMzFFZgYKFKVNkeTZOy8Nbol2aRSrVKLhha4ZNirZIjPy4XSemYiBEi9tPBMJYsatbOo4dYdCXh7vMKPfxoUhFBk-UWkFw4KN-9Zcy5yQeXszfxWPGz-bIBiMkoFhNKMCw6x0s4NTjYXbI18mWSggr7kx24dGPId9Ry4VVdHg","text":"AI 我是誰"},"webhookEventId":"01KDHSW3W2X4EY5JYKPW716HX0","deliveryContext":{"isRedelivery":false},"timestamp":1766902861189,"source":{"type":"user","userId":"U63019324a610a0977db9bdaed8d8f469"},"replyToken":"f154e71c69f340da8a0468f4b3754b0f","mode":"active"}]}
# BODY:  {"destination":"U967a7ddada8eaab9e15d60d0f3029ae7","events":[{"type":"message","message":{"type":"text","id":"594033499427307708","quoteToken":"MzsCpkG_hURPbOrOgWCkhPFejryrshIrTl_0gYkVLnlgZzSY1kjTDiqF1NL0MXT0BDqv9MGAuCqBqMUli8yk6zmorkT2Gv449BvN8J1o1Dpz6dw6dAmhvG_oPgP5zF353G68tAzIYg2n2ssk3BlpQA","markAsReadToken":"Z5YmbPubtpgAcLv5OrJTVVEywZ1g56uv5_9z6VjwDUa35LMzFFZgYKFKVNkeTZOy8Nbol2aRSrVKLhha4ZNirZIjPy4XSemYiBEi9tPBMJYsatbOo4dYdCXh7vMKPfxoUhFBk-UWkFw4KN-9Zcy5yQeXszfxWPGz-bIBiMkoFhNKMCw6x0s4NTjYXbI18mWSggr7kx24dGPId9Ry4VVdHg","text":"AI 我是誰"},"webhookEventId":"01KDHSW3W2X4EY5JYKPW716HX0","deliveryContext":{"isRedelivery":false},"timestamp":1766902861189,"source":{"type":"user","userId":"U63019324a610a0977db9bdaed8d8f469"},"replyToken":"f154e71c69f340da8a0468f4b3754b0f","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [28/Dec/2025 06:21:05] "POST / HTTP/1.1" 200 -
# INFO:__main__:Request body: {"destination":"U967a7ddada8eaab9e15d60d0f3029ae7","events":[{"type":"message","message":{"type":"text","id":"594033674447224850","quoteToken":"RC-KmlNGzf_gXHrFjnJYmpuUBeKzZXPk8_j_qqR2t9pZnfrJjkfMfTJQUSwmVMMdEtWF3L6zvWJaTMpgo11J_Wz9rVdss30boUA4v3M9A9iqH31rmrDD73ACeTwgNatMFhg4CVkOUgFnpYr0S9ci7g","markAsReadToken":"y7vB-HL6SbxycsFs7tvuG8C6JXqJ9rNRaUUzxlde4FtlVOzwru6mGtiR23oPgyP51yJydokDhs50w7TAP2Nml7hfAdY0ZbfcZ5rnvHRKXtiHtUCr_q6YaPiEou2oC_0xt6dwmwcHb__ohtAL1famRCWQsGa0Wh9RoOrkbEoPc3Kp1t5e9HYdVL7iQs0VH_NFS0QI0HZkZYQPhsr9rwMCLA","text":"AI 簡介明新科技大學"},"webhookEventId":"01KDHSZ9MC9E3CX69HF9YCAWTS","deliveryContext":{"isRedelivery":false},"timestamp":1766902965508,"source":{"type":"user","userId":"U63019324a610a0977db9bdaed8d8f469"},"replyToken":"f0e5fc81faa142909aa877224dde1cf0","mode":"active"}]}
# BODY:  {"destination":"U967a7ddada8eaab9e15d60d0f3029ae7","events":[{"type":"message","message":{"type":"text","id":"594033674447224850","quoteToken":"RC-KmlNGzf_gXHrFjnJYmpuUBeKzZXPk8_j_qqR2t9pZnfrJjkfMfTJQUSwmVMMdEtWF3L6zvWJaTMpgo11J_Wz9rVdss30boUA4v3M9A9iqH31rmrDD73ACeTwgNatMFhg4CVkOUgFnpYr0S9ci7g","markAsReadToken":"y7vB-HL6SbxycsFs7tvuG8C6JXqJ9rNRaUUzxlde4FtlVOzwru6mGtiR23oPgyP51yJydokDhs50w7TAP2Nml7hfAdY0ZbfcZ5rnvHRKXtiHtUCr_q6YaPiEou2oC_0xt6dwmwcHb__ohtAL1famRCWQsGa0Wh9RoOrkbEoPc3Kp1t5e9HYdVL7iQs0VH_NFS0QI0HZkZYQPhsr9rwMCLA","text":"AI 簡介明新科技大學"},"webhookEventId":"01KDHSZ9MC9E3CX69HF9YCAWTS","deliveryContext":{"isRedelivery":false},"timestamp":1766902965508,"source":{"type":"user","userId":"U63019324a610a0977db9bdaed8d8f469"},"replyToken":"f0e5fc81faa142909aa877224dde1cf0","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [28/Dec/2025 06:22:55] "POST / HTTP/1.1" 200 -
